# %%
Making My Second Project Named 'Password Generator'.

# %%
import random
import string

use_digits = input("Include numbers? (yes/no): " )
use_symbols = input("Include symbols? (yes/no): " )
characters = string.ascii_letters 
if use_digits == "yes":
    characters += string.digits
if use_symbols == "yes":
    characters += string.punctuation

password = ""
for i in range(length):
    password += random.choice(characters)


print("Your password is: " , password)
if length < 4:
    print("Password too short!")
elif length < 10:
    print("Medium password ")
else:
    print("Strong password")
    
print(" Generating your secure password...")
# Out:
# Include numbers? (yes/no):  yes
# Include symbols? (yes/no):  yes
# Your password is:  uJz(?w4G
# Medium password
#  Generating your secure password...
